# %% [markdown]
# ## Model-Training with pretrained weights from Yolo11n-cls

# %%
# !nvidia-smi
# Out:
# Thu Dec 11 16:58:30 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 560.94                 Driver Version: 560.94         CUDA Version: 12.6     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                  Driver-Model | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA GeForce GTX 1660      WDDM  |   00000000:08:00.0  On |                  N/A |
# | 38%   41C    P0             24W /  130W |    1260MiB /   6144MiB |      2%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI        PID   Type   Process name                              GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |    0   N/A  N/A      2800    C+G   ...s (x86)\AusweisApp2\AusweisApp2.exe      N/A      |
# |    0   N/A  N/A      2892    C+G   ...s\System32\ApplicationFrameHost.exe      N/A      |
# |    0   N/A  N/A      4200    C+G   ..._x64__cw5n1h2txyewy\WidgetBoard.exe      N/A      |
# |    0   N/A  N/A      4540    C+G   C:\OSGeo4W\bin\qgis-bin.exe                 N/A      |
# |    0   N/A  N/A      5428    C+G   ..._x64__8wekyb3d8bbwe\M365Copilot.exe      N/A      |
# |    0   N/A  N/A      7768    C+G   ...2txyewy\StartMenuExperienceHost.exe      N/A      |
# |    0   N/A  N/A      9452    C+G   C:\Windows\explorer.exe                     N/A      |
# |    0   N/A  N/A     10100    C+G   ...m Files\Mozilla Firefox\firefox.exe      N/A      |
# |    0   N/A  N/A     10336    C+G   ...panion\Application\WebCompanion.exe      N/A      |
# |    0   N/A  N/A     10388    C+G   C:\Windows\System32\ShellHost.exe           N/A      |
# |    0   N/A  N/A     10416    C+G   ...on\142.0.3595.94\msedgewebview2.exe      N/A      |
# |    0   N/A  N/A     11072    C+G   ...GeForce Experience\NVIDIA Share.exe      N/A      |
# |    0   N/A  N/A     11332    C+G   ...nt.CBS_cw5n1h2txyewy\SearchHost.exe      N/A      |
# |    0   N/A  N/A     11624    C+G   ...inaries\Win64\EpicGamesLauncher.exe      N/A      |
# |    0   N/A  N/A     11992    C+G   ...55.0_x64__8wekyb3d8bbwe\Copilot.exe      N/A      |
# |    0   N/A  N/A     12164    C+G   ...CBS_cw5n1h2txyewy\TextInputHost.exe      N/A      |
# |    0   N/A  N/A     13172    C+G   ...on\142.0.3595.94\msedgewebview2.exe      N/A      |
# |    0   N/A  N/A     13212    C+G   ...on\142.0.3595.94\msedgewebview2.exe      N/A      |
# |    0   N/A  N/A     13840    C+G   ...siveControlPanel\SystemSettings.exe      N/A      |
# |    0   N/A  N/A     15256    C+G   ...on\142.0.3595.94\msedgewebview2.exe      N/A      |
# |    0   N/A  N/A     15508    C+G   ...m Files\Mozilla Firefox\firefox.exe      N/A      |
# |    0   N/A  N/A     15512    C+G   ...m Files\MuseHub\current\MuseHub.exe      N/A      |
# |    0   N/A  N/A     15920    C+G   ...\cef\cef.win7x64\steamwebhelper.exe      N/A      |
# |    0   N/A  N/A     16084    C+G   ...cal\Microsoft\OneDrive\OneDrive.exe      N/A      |
# |    0   N/A  N/A     16248    C+G   ...ne\Binaries\Win64\EpicWebHelper.exe      N/A      |
# |    0   N/A  N/A     16844    C+G   ...B\system_tray\lghub_system_tray.exe      N/A      |
# |    0   N/A  N/A     17136    C+G   ...\Update Notifier\QMxNetworkSync.exe      N/A      |
# |    0   N/A  N/A     17452    C+G   ...64__cv1g1gvanyjgm\WhatsApp.Root.exe      N/A      |
# |    0   N/A  N/A     18836    C+G   ...m Files\Mozilla Firefox\firefox.exe      N/A      |
# |    0   N/A  N/A     19276    C+G   ...Programs\Microsoft VS Code\Code.exe      N/A      |
# +-----------------------------------------------------------------------------------------+

# %%
from ultralytics import YOLO
from pathlib import Path
import os
import shutil

# %%
# Paths
DATA_PATH = Path("../data/images_classified")  
PROJECT_NAME = "greenery_classification"       # name of the training run
RUNS_PATH = Path("../runs")                    # output directory

# %%
# Training parameters
MODEL_SIZE = "n" # nano, the smalllest model
EPOCHS = 50
BATCH_SIZE = 32 # can be higher with better GPU
IMAGE_SIZE = 224
PATIENCE = 20  # early stopping patience
AUGMENT = True
DEVICE = "cuda" # using GPU

CLASS_NAMES = ["greenery", "non_greenery"]

# %%
# TRAINING

def train_model():
    """Trains the YOLO classification model."""
    print("\n" + "=" * 70)
    print(" STARTING TRAINING")
    print("=" * 70)

    model_path = f"yolo11{MODEL_SIZE}-cls.pt"

    # Check pretrained weights
    weights_dir = Path("./weights")
    weights_dir.mkdir(exist_ok=True)
    weight_file = weights_dir / model_path

    # Load model
    model = YOLO(str(weight_file))

    # Train
    results = model.train(
        data=str(DATA_PATH),
        epochs=EPOCHS,
        batch=BATCH_SIZE,
        imgsz=IMAGE_SIZE,
        patience=PATIENCE,
        project=str(RUNS_PATH),
        name=PROJECT_NAME,
        exist_ok=True,
        plots=True,
        augment=AUGMENT,
        device=DEVICE
    )

    best_model_path = RUNS_PATH / PROJECT_NAME / "weights" / "best.pt"
    print(f"\n Best model saved at: {best_model_path}")

    return model, best_model_path

# VALIDATION + TEST

def evaluate_model(model_path):
    """Runs validation and test."""
    model = YOLO(str(model_path))

    # Validation
    val_metrics = model.val(split="val")
    print(f"\n Validation Top-1 Accuracy: {val_metrics.top1:.2%}")

    # Test
    test_metrics = model.val(split="test")
    print(f"\n Test Top-1 Accuracy: {test_metrics.top1:.2%}")

    return val_metrics, test_metrics

# EXAMPLE PREDICTIONS

def predict_examples(model_path, num_samples=10):
    """Predicts several random samples from the test set."""
    model = YOLO(str(model_path))

    test_images = []
    for cls in CLASS_NAMES:
        cls_images = list((DATA_PATH / "test" / cls).glob("*.jpg"))[:num_samples // 2]
        test_images.extend(cls_images)

    if not test_images:
        print(" No test images found!")
        return

    print(f"\n Predictions for {len(test_images)} sample images:\n")

    for img_path in test_images:
        results = model.predict(img_path, verbose=False)
        probs = results[0].probs

        top1_idx = probs.top1
        top1_conf = probs.top1conf.item()

        predicted_class = CLASS_NAMES[top1_idx]
        true_class = img_path.parent.name

        status = "✅" if predicted_class == true_class else "❌"

        print(
            f"{status} {img_path.name:<30} "
            f"True: {true_class:<13} | Pred: {predicted_class:<13} "
            f"({top1_conf:.2%})"
        )

def main():
    print(" YOLO GREENERY CLASSIFICATION PIPELINE")


    if not DATA_PATH.exists():
        print(f" Dataset not found: {DATA_PATH}")
        return

    # Training
    model, best_model_path = train_model()

    # Evaluation
    val_metrics, test_metrics = evaluate_model(best_model_path)

    # Example Predictions
    predict_examples(best_model_path, num_samples=20)

    print("\n PIPELINE COMPLETE!")
    print(f"All results saved in: {RUNS_PATH / PROJECT_NAME}")


if __name__ == "__main__":
    main()
# Out:
#  YOLO GREENERY CLASSIFICATION PIPELINE
#
# ======================================================================
#  STARTING TRAINING
# ======================================================================
# Ultralytics 8.3.235  Python-3.11.3 torch-2.5.1+cu118 CUDA:0 (NVIDIA GeForce GTX 1660, 6144MiB)
# engine\trainer: agnostic_nms=False, amp=True, augment=True, auto_augment=randaugment, batch=32, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=..\data\images_classified, degrees=0.0, deterministic=True, device=0, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, epochs=50, erasing=0.4, exist_ok=True, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=224, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=weights\yolo11n-cls.pt, momentum=0.937, mosaic=1.0, multi_scale=False, name=greenery_classification, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=20, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=..\runs, rect=False, resume=False, retina_masks=False, save=True, save_conf=False, save_crop=False, save_dir=D:\Dokumente\GeoAI\GeoAI_and_DL\runs\greenery_classification, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=classify, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# train: D:\Dokumente\GeoAI\GeoAI_and_DL\data\images_classified\train... found 1696 images in 2 classes
# val: D:\Dokumente\GeoAI\GeoAI_and_DL\data\images_classified\val... found 500 images in 2 classes
# test: D:\Dokumente\GeoAI\GeoAI_and_DL\data\images_classified\test... found 497 images in 2 classes
# Overriding model.yaml nc=80 with nc=2
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      6640  ultralytics.nn.modules.block.C3k2            [32, 64, 1, False, 0.25]
#   3                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#   4                  -1  1     26080  ultralytics.nn.modules.block.C3k2            [64, 128, 1, False, 0.25]
#   5                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#   6                  -1  1     87040  ultralytics.nn.modules.block.C3k2            [128, 128, 1, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    346112  ultralytics.nn.modules.block.C3k2            [256, 256, 1, True]
#   9                  -1  1    249728  ultralytics.nn.modules.block.C2PSA           [256, 256, 1]
#  10                  -1  1    332802  ultralytics.nn.modules.head.Classify         [256, 2]
# YOLO11n-cls summary: 86 layers, 1,533,666 parameters, 1,533,666 gradients, 3.3 GFLOPs
# Transferred 234/236 items from pretrained weights
# WARNING AMP: checks failed . AMP training on NVIDIA GeForce GTX 1660 GPU may cause NaN losses or zero-mAP results, so AMP will be disabled during training.
# train: Fast image access  (ping: 0.10.0 ms, read: 2.02.2 MB/s, size: 8.1 KB)
# train: Scanning D:\Dokumente\GeoAI\GeoAI_and_DL\data\images_classified\train... 1696 images, 0 corrupt: 100% ━━━━━━━━━━━━ 1696/1696 1.7Mit/s 0.0s
# val: Fast image access  (ping: 0.10.0 ms, read: 1.62.3 MB/s, size: 9.5 KB)
# val: Scanning D:\Dokumente\GeoAI\GeoAI_and_DL\data\images_classified\val... 500 images, 0 corrupt: 100% ━━━━━━━━━━━━ 500/500 497.7Kit/s 0.0s
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.001667, momentum=0.9) with parameter groups 39 weight(decay=0.0), 40 weight(decay=0.0005), 40 bias(decay=0.0)
# Image sizes 224 train, 224 val
# Using 8 dataloader workers
# Logging results to D:\Dokumente\GeoAI\GeoAI_and_DL\runs\greenery_classification
# Starting training for 50 epochs...
#
#       Epoch    GPU_mem       loss  Instances       Size
#        1/50     0.766G     0.4193         32        224: 100% ━━━━━━━━━━━━ 53/53 5.8it/s 9.1s<0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 8/8 15.9it/s 0.5s0.3s
#                    all       0.93          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#        2/50     0.816G     0.3189         32        224: 100% ━━━━━━━━━━━━ 53/53 12.9it/s 4.1s0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 8/8 35.0it/s 0.2s0.4s
#                    all        0.9          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#        3/50     0.816G     0.3053         32        224: 100% ━━━━━━━━━━━━ 53/53 14.3it/s 3.7s0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 8/8 36.0it/s 0.2s0.4s
#                    all      0.892          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#        4/50     0.816G     0.3128         32        224: 100% ━━━━━━━━━━━━ 53/53 14.3it/s 3.7s0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 8/8 35.6it/s 0.2s0.4s
#                    all       0.92          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#        5/50     0.816G     0.2749         32        224: 100% ━━━━━━━━━━━━ 53/53 14.4it/s 3.7s0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 8/8 35.1it/s 0.2s0.4s
#                    all      0.932          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#        6/50     0.816G     0.3245         32        224: 100% ━━━━━━━━━━━━ 53/53 13.3it/s 4.0s0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 8/8 36.1it/s 0.2s0.4s
#                    all      0.898          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#        7/50     0.816G     0.2632         32        224: 100% ━━━━━━━━━━━━ 53/53 14.5it/s 3.6s0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 8/8 35.7it/s 0.2s0.4s
#                    all      0.906          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#        8/50     0.816G     0.2619         32        224: 100% ━━━━━━━━━━━━ 53/53 13.7it/s 3.9s0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 8/8 36.2it/s 0.2s0.4s
#                    all      0.886          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#        9/50     0.816G      0.221         32        224: 100% ━━━━━━━━━━━━ 53/53 14.4it/s 3.7s0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 8/8 35.9it/s 0.2s0.4s
#                    all      0.926          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       10/50     0.816G      0.229         32        224: 100% ━━━━━━━━━━━━ 53/53 14.2it/s 3.7s0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 8/8 35.9it/s 0.2s0.4s
#                    all      0.934          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       11/50     0.816G     0.2176         32        224: 100% ━━━━━━━━━━━━ 53/53 14.5it/s 3.7s0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 8/8 35.9it/s 0.2s0.4s
#                    all      0.902          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       12/50     0.816G     0.2197         32        224: 100% ━━━━━━━━━━━━ 53/53 14.3it/s 3.7s0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 8/8 36.2it/s 0.2s0.4s
#                    all      0.946          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       13/50     0.816G     0.2106         32        224: 100% ━━━━━━━━━━━━ 53/53 14.2it/s 3.7s0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 8/8 36.3it/s 0.2s0.4s
#                    all       0.94          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       14/50     0.816G     0.2222         32        224: 100% ━━━━━━━━━━━━ 53/53 14.3it/s 3.7s0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 8/8 36.2it/s 0.2s0.4s
#                    all      0.948          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       15/50     0.816G      0.182         32        224: 100% ━━━━━━━━━━━━ 53/53 14.3it/s 3.7s0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 8/8 35.9it/s 0.2s0.4s
#                    all      0.942          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       16/50     0.816G     0.2107         32        224: 100% ━━━━━━━━━━━━ 53/53 14.3it/s 3.7s0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 8/8 35.9it/s 0.2s0.4s
#                    all       0.93          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       17/50     0.816G     0.2308         32        224: 100% ━━━━━━━━━━━━ 53/53 14.4it/s 3.7s0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 8/8 35.8it/s 0.2s0.4s
#                    all      0.952          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       18/50     0.816G     0.2124         32        224: 100% ━━━━━━━━━━━━ 53/53 14.4it/s 3.7s0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 8/8 35.9it/s 0.2s0.4s
#                    all       0.94          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       19/50     0.816G     0.1986         32        224: 100% ━━━━━━━━━━━━ 53/53 14.5it/s 3.7s0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 8/8 35.4it/s 0.2s0.4s
#                    all      0.942          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       20/50     0.816G     0.1865         32        224: 100% ━━━━━━━━━━━━ 53/53 14.4it/s 3.7s0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 8/8 36.1it/s 0.2s0.4s
#                    all      0.944          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       21/50     0.816G     0.1982         32        224: 100% ━━━━━━━━━━━━ 53/53 14.5it/s 3.7s0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 8/8 36.2it/s 0.2s0.4s
#                    all      0.912          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       22/50     0.816G     0.1981         32        224: 100% ━━━━━━━━━━━━ 53/53 14.5it/s 3.7s0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 8/8 36.2it/s 0.2s0.4s
#                    all       0.95          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       23/50     0.816G     0.1999         32        224: 100% ━━━━━━━━━━━━ 53/53 14.2it/s 3.7s0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 8/8 36.1it/s 0.2s0.4s
#                    all      0.944          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       24/50     0.816G     0.2132         32        224: 100% ━━━━━━━━━━━━ 53/53 14.4it/s 3.7s0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 8/8 35.6it/s 0.2s0.4s
#                    all      0.944          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       25/50     0.816G     0.1821         32        224: 100% ━━━━━━━━━━━━ 53/53 14.4it/s 3.7s0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 8/8 36.1it/s 0.2s0.4s
#                    all      0.934          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       26/50     0.816G     0.1718         32        224: 100% ━━━━━━━━━━━━ 53/53 14.0it/s 3.8s0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 8/8 35.8it/s 0.2s0.4s
#                    all       0.95          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       27/50     0.816G     0.1886         32        224: 100% ━━━━━━━━━━━━ 53/53 14.4it/s 3.7s0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 8/8 35.1it/s 0.2s0.4s
#                    all      0.926          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       28/50     0.816G     0.1923         32        224: 100% ━━━━━━━━━━━━ 53/53 14.4it/s 3.7s0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 8/8 35.8it/s 0.2s0.4s
#                    all      0.948          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       29/50     0.816G     0.1891         32        224: 100% ━━━━━━━━━━━━ 53/53 14.4it/s 3.7s0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 8/8 35.6it/s 0.2s0.4s
#                    all      0.946          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       30/50     0.816G     0.1871         32        224: 100% ━━━━━━━━━━━━ 53/53 14.2it/s 3.7s0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 8/8 35.9it/s 0.2s0.4s
#                    all      0.954          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       31/50     0.816G     0.1994         32        224: 100% ━━━━━━━━━━━━ 53/53 14.3it/s 3.7s0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 8/8 35.9it/s 0.2s0.4s
#                    all      0.954          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       32/50     0.816G      0.197         32        224: 100% ━━━━━━━━━━━━ 53/53 14.4it/s 3.7s0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 8/8 36.1it/s 0.2s0.4s
#                    all       0.96          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       33/50     0.816G     0.1708         32        224: 100% ━━━━━━━━━━━━ 53/53 13.5it/s 3.9s0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 8/8 34.9it/s 0.2s0.4s
#                    all      0.958          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       34/50     0.816G     0.1876         32        224: 100% ━━━━━━━━━━━━ 53/53 13.7it/s 3.9s0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 8/8 35.7it/s 0.2s0.4s
#                    all       0.96          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       35/50     0.816G      0.165         32        224: 100% ━━━━━━━━━━━━ 53/53 14.3it/s 3.7s0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 8/8 36.0it/s 0.2s0.4s
#                    all       0.96          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       36/50     0.816G     0.1641         32        224: 100% ━━━━━━━━━━━━ 53/53 14.0it/s 3.8s0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 8/8 35.7it/s 0.2s0.4s
#                    all      0.956          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       37/50     0.816G     0.1551         32        224: 100% ━━━━━━━━━━━━ 53/53 14.3it/s 3.7s0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 8/8 35.2it/s 0.2s0.4s
#                    all      0.948          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       38/50     0.816G     0.1496         32        224: 100% ━━━━━━━━━━━━ 53/53 14.4it/s 3.7s0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 8/8 36.1it/s 0.2s0.4s
#                    all       0.95          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       39/50     0.816G     0.1633         32        224: 100% ━━━━━━━━━━━━ 53/53 14.2it/s 3.7s0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 8/8 35.8it/s 0.2s0.4s
#                    all      0.942          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       40/50     0.816G     0.1551         32        224: 100% ━━━━━━━━━━━━ 53/53 14.4it/s 3.7s0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 8/8 36.3it/s 0.2s0.4s
#                    all      0.946          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       41/50     0.816G     0.1474         32        224: 100% ━━━━━━━━━━━━ 53/53 9.4it/s 5.6s<0.2s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 8/8 22.7it/s 0.4s0.2s
#                    all      0.948          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       42/50     0.816G     0.1833         32        224: 100% ━━━━━━━━━━━━ 53/53 14.1it/s 3.7s0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 8/8 36.1it/s 0.2s0.4s
#                    all      0.952          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       43/50     0.816G     0.1466         32        224: 100% ━━━━━━━━━━━━ 53/53 14.2it/s 3.7s0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 8/8 36.0it/s 0.2s0.4s
#                    all       0.96          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       44/50     0.816G     0.1607         32        224: 100% ━━━━━━━━━━━━ 53/53 14.3it/s 3.7s0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 8/8 35.1it/s 0.2s0.4s
#                    all      0.966          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       45/50     0.816G     0.1444         32        224: 100% ━━━━━━━━━━━━ 53/53 14.3it/s 3.7s0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 8/8 35.5it/s 0.2s0.4s
#                    all       0.96          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       46/50     0.816G      0.149         32        224: 100% ━━━━━━━━━━━━ 53/53 13.9it/s 3.8s0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 8/8 35.9it/s 0.2s0.4s
#                    all      0.958          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       47/50     0.816G     0.1277         32        224: 100% ━━━━━━━━━━━━ 53/53 14.4it/s 3.7s0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 8/8 35.6it/s 0.2s0.4s
#                    all       0.96          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       48/50     0.816G     0.1309         32        224: 100% ━━━━━━━━━━━━ 53/53 13.4it/s 3.9s0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 8/8 35.4it/s 0.2s0.4s
#                    all       0.96          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       49/50     0.816G     0.1484         32        224: 100% ━━━━━━━━━━━━ 53/53 14.1it/s 3.8s0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 8/8 34.5it/s 0.2s0.4s
#                    all      0.964          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       50/50     0.816G     0.1287         32        224: 100% ━━━━━━━━━━━━ 53/53 14.4it/s 3.7s0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 8/8 35.4it/s 0.2s0.4s
#                    all      0.966          1
#
# 50 epochs completed in 0.072 hours.
# Optimizer stripped from D:\Dokumente\GeoAI\GeoAI_and_DL\runs\greenery_classification\weights\last.pt, 3.2MB
# Optimizer stripped from D:\Dokumente\GeoAI\GeoAI_and_DL\runs\greenery_classification\weights\best.pt, 3.2MB
#
# Validating D:\Dokumente\GeoAI\GeoAI_and_DL\runs\greenery_classification\weights\best.pt...
# Ultralytics 8.3.235  Python-3.11.3 torch-2.5.1+cu118 CUDA:0 (NVIDIA GeForce GTX 1660, 6144MiB)
# YOLO11n-cls summary (fused): 47 layers, 1,528,586 parameters, 0 gradients, 3.2 GFLOPs
# train: D:\Dokumente\GeoAI\GeoAI_and_DL\data\images_classified\train... found 1696 images in 2 classes
# val: D:\Dokumente\GeoAI\GeoAI_and_DL\data\images_classified\val... found 500 images in 2 classes
# test: D:\Dokumente\GeoAI\GeoAI_and_DL\data\images_classified\test... found 497 images in 2 classes
# WARNING ClassificationModel does not support 'augment=True' prediction. Reverting to single-scale prediction.
#                classes   top1_acc   top5_acc: 12% ━─────────── 1/8 1.6it/s 0.2s<4.3sWARNING ClassificationModel does not support 'augment=True' prediction. Reverting to single-scale prediction.
# WARNING ClassificationModel does not support 'augment=True' prediction. Reverting to single-scale prediction.
#                classes   top1_acc   top5_acc: 38% ━━━━──────── 3/8 6.7it/s 0.3s<0.7sWARNING ClassificationModel does not support 'augment=True' prediction. Reverting to single-scale prediction.
# WARNING ClassificationModel does not support 'augment=True' prediction. Reverting to single-scale prediction.
#                classes   top1_acc   top5_acc: 62% ━━━━━━━───── 5/8 10.0it/s 0.4s<0.3sWARNING ClassificationModel does not support 'augment=True' prediction. Reverting to single-scale prediction.
# WARNING ClassificationModel does not support 'augment=True' prediction. Reverting to single-scale prediction.
# WARNING ClassificationModel does not support 'augment=True' prediction. Reverting to single-scale prediction.
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 8/8 16.3it/s 0.5s
#                    all      0.966          1
# Speed: 0.1ms preprocess, 0.6ms inference, 0.0ms loss, 0.0ms postprocess per image
# Results saved to D:\Dokumente\GeoAI\GeoAI_and_DL\runs\greenery_classification
#
#  Best model saved at: ..\runs\greenery_classification\weights\best.pt
# Ultralytics 8.3.235  Python-3.11.3 torch-2.5.1+cu118 CUDA:0 (NVIDIA GeForce GTX 1660, 6144MiB)
# YOLO11n-cls summary (fused): 47 layers, 1,528,586 parameters, 0 gradients, 3.2 GFLOPs
# train: D:\Dokumente\GeoAI\GeoAI_and_DL\data\images_classified\train... found 1696 images in 2 classes
# val: D:\Dokumente\GeoAI\GeoAI_and_DL\data\images_classified\val... found 500 images in 2 classes
# test: D:\Dokumente\GeoAI\GeoAI_and_DL\data\images_classified\test... found 497 images in 2 classes
# val: Fast image access  (ping: 0.10.0 ms, read: 82.820.1 MB/s, size: 9.5 KB)
# val: Scanning D:\Dokumente\GeoAI\GeoAI_and_DL\data\images_classified\val... 500 images, 0 corrupt: 100% ━━━━━━━━━━━━ 500/500 498.3Kit/s 0.0s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 32/32 33.5it/s 1.0s0.1s
#                    all      0.966          1
# Speed: 0.1ms preprocess, 1.4ms inference, 0.0ms loss, 0.0ms postprocess per image
# Results saved to D:\Dokumente\GeoAI\GeoAI_and_DL\runs\classify\val
#
#  Validation Top-1 Accuracy: 96.60%
# Ultralytics 8.3.235  Python-3.11.3 torch-2.5.1+cu118 CUDA:0 (NVIDIA GeForce GTX 1660, 6144MiB)
# train: D:\Dokumente\GeoAI\GeoAI_and_DL\data\images_classified\train... found 1696 images in 2 classes
# val: D:\Dokumente\GeoAI\GeoAI_and_DL\data\images_classified\val... found 500 images in 2 classes
# test: D:\Dokumente\GeoAI\GeoAI_and_DL\data\images_classified\test... found 497 images in 2 classes
# test: Fast image access  (ping: 0.10.0 ms, read: 12.115.4 MB/s, size: 10.3 KB)
# test: Scanning D:\Dokumente\GeoAI\GeoAI_and_DL\data\images_classified\test... 497 images, 0 corrupt: 100% ━━━━━━━━━━━━ 497/497 489.7Kit/s 0.0s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 32/32 34.9it/s 0.9s0.1s
#                    all      0.966          1
# Speed: 0.1ms preprocess, 1.1ms inference, 0.0ms loss, 0.0ms postprocess per image
# Results saved to D:\Dokumente\GeoAI\GeoAI_and_DL\runs\classify\val2
#
#  Test Top-1 Accuracy: 96.58%
#
#  Predictions for 20 sample images:
#
# ✅ Msimbazi_Merged_ycbr_test_patch_1.jpg True: greenery      | Pred: greenery      (91.65%)
# ✅ Msimbazi_Merged_ycbr_test_patch_1001.jpg True: greenery      | Pred: greenery      (99.90%)
# ✅ Msimbazi_Merged_ycbr_test_patch_1008.jpg True: greenery      | Pred: greenery      (74.87%)
# ✅ Msimbazi_Merged_ycbr_test_patch_1012.jpg True: greenery      | Pred: greenery      (99.88%)
# ✅ Msimbazi_Merged_ycbr_test_patch_1018.jpg True: greenery      | Pred: greenery      (99.88%)
# ✅ Msimbazi_Merged_ycbr_test_patch_1019.jpg True: greenery      | Pred: greenery      (54.50%)
# ✅ Msimbazi_Merged_ycbr_test_patch_1023.jpg True: greenery      | Pred: greenery      (58.55%)
# ✅ Msimbazi_Merged_ycbr_test_patch_103.jpg True: greenery      | Pred: greenery      (99.97%)
# ❌ Msimbazi_Merged_ycbr_test_patch_1036.jpg True: greenery      | Pred: non_greenery  (69.19%)
# ✅ Msimbazi_Merged_ycbr_test_patch_1037.jpg True: greenery      | Pred: greenery      (64.31%)
# ✅ Msimbazi_Merged_ycbr_test_patch_1000.jpg True: non_greenery  | Pred: non_greenery  (99.95%)
# ✅ Msimbazi_Merged_ycbr_test_patch_1009.jpg True: non_greenery  | Pred: non_greenery  (99.67%)
# ✅ Msimbazi_Merged_ycbr_test_patch_1022.jpg True: non_greenery  | Pred: non_greenery  (99.45%)
# ✅ Msimbazi_Merged_ycbr_test_patch_1026.jpg True: non_greenery  | Pred: non_greenery  (99.97%)
# ✅ Msimbazi_Merged_ycbr_test_patch_1033.jpg True: non_greenery  | Pred: non_greenery  (99.99%)
# ✅ Msimbazi_Merged_ycbr_test_patch_1034.jpg True: non_greenery  | Pred: non_greenery  (100.00%)
# ✅ Msimbazi_Merged_ycbr_test_patch_1046.jpg True: non_greenery  | Pred: non_greenery  (100.00%)
# ✅ Msimbazi_Merged_ycbr_test_patch_1051.jpg True: non_greenery  | Pred: non_greenery  (100.00%)
# ✅ Msimbazi_Merged_ycbr_test_patch_1053.jpg True: non_greenery  | Pred: non_greenery  (100.00%)
# ✅ Msimbazi_Merged_ycbr_test_patch_106.jpg True: non_greenery  | Pred: non_greenery  (100.00%)
#
#  PIPELINE COMPLETE!
# All results saved in: ..\runs\greenery_classification
