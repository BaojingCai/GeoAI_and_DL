# %%
from ultralytics import YOLO
from pathlib import Path
import os
import shutil

# Paths
DATA_PATH = Path("../data/images_augmented")  
PROJECT_NAME = "greenery_classification"       # name of the training run
RUNS_PATH = Path("../runs")                    # output directory

# Training parameters
MODEL_SIZE = "n"      # 'n', 's', 'm', 'l', 'x' (nano → xlarge)
EPOCHS = 50
BATCH_SIZE = 16
IMAGE_SIZE = 128
PATIENCE = 20         # early stopping patience

CLASS_NAMES = ["greenery", "non_greenery"]

# TRAINING

def train_model():
    """Trains the YOLO classification model."""
    print("\n" + "=" * 70)
    print(" STARTING TRAINING")
    print("=" * 70)

    model_path = f"yolov8{MODEL_SIZE}-cls.pt"

    # Check pretrained weights
    weights_dir = Path("./weights")
    weights_dir.mkdir(exist_ok=True)
    weight_file = weights_dir / model_path

    if not weight_file.exists():
        import urllib.request
        url = f"https://github.com/ultralytics/assets/releases/download/v0.0.0/{model_path}"
        print(f"⬇ Downloading pretrained weights: {url}")
        urllib.request.urlretrieve(url, weight_file)
        print(" Download complete.")

    # Load model
    model = YOLO(str(weight_file))

    # Train
    results = model.train(
        data=str(DATA_PATH),
        epochs=EPOCHS,
        batch=BATCH_SIZE,
        imgsz=IMAGE_SIZE,
        patience=PATIENCE,
        project=str(RUNS_PATH),
        name=PROJECT_NAME,
        exist_ok=True,
        plots=True,
    )

    best_model_path = RUNS_PATH / PROJECT_NAME / "weights" / "best.pt"
    print(f"\n Best model saved at: {best_model_path}")

    return model, best_model_path

# VALIDATION + TEST

def evaluate_model(model_path):
    """Runs validation and test."""
    model = YOLO(str(model_path))

    # Validation
    val_metrics = model.val(split="val")
    print(f"\n📊 Validation Top-1 Accuracy: {val_metrics.top1:.2%}")

    # Test
    test_metrics = model.val(split="test")
    print(f"\n📊 Test Top-1 Accuracy: {test_metrics.top1:.2%}")

    return val_metrics, test_metrics

# EXAMPLE PREDICTIONS

def predict_examples(model_path, num_samples=10):
    """Predicts several random samples from the test set."""
    model = YOLO(str(model_path))

    test_images = []
    for cls in CLASS_NAMES:
        cls_images = list((DATA_PATH / "test" / cls).glob("*.jpg"))[:num_samples // 2]
        test_images.extend(cls_images)

    if not test_images:
        print(" No test images found!")
        return

    print(f"\n Predictions for {len(test_images)} sample images:\n")

    for img_path in test_images:
        results = model.predict(img_path, verbose=False)
        probs = results[0].probs

        top1_idx = probs.top1
        top1_conf = probs.top1conf.item()

        predicted_class = CLASS_NAMES[top1_idx]
        true_class = img_path.parent.name

        status = "✅" if predicted_class == true_class else "❌"

        print(
            f"{status} {img_path.name:<30} "
            f"True: {true_class:<13} | Pred: {predicted_class:<13} "
            f"({top1_conf:.2%})"
        )


# MAIN

def main():
    print(" YOLO GREENERY CLASSIFICATION PIPELINE")


    if not DATA_PATH.exists():
        print(f" Dataset not found: {DATA_PATH}")
        return

    # Training
    model, best_model_path = train_model()

    # Evaluation
    val_metrics, test_metrics = evaluate_model(best_model_path)

    # Example Predictions
    predict_examples(best_model_path, num_samples=20)

    print("\n PIPELINE COMPLETE!")
    print(f"All results saved in: {RUNS_PATH / PROJECT_NAME}")


if __name__ == "__main__":
    main()
# Out:
#  YOLO GREENERY CLASSIFICATION PIPELINE
#
# ======================================================================
#  STARTING TRAINING
# ======================================================================
# ⬇ Downloading pretrained weights: https://github.com/ultralytics/assets/releases/download/v0.0.0/yolov8n-cls.pt
#  Download complete.
# Ultralytics 8.3.228  Python-3.11.3 torch-2.9.1+cpu CPU (AMD Ryzen 5 2600 Six-Core Processor)
# engine\trainer: agnostic_nms=False, amp=True, augment=False, auto_augment=randaugment, batch=16, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=..\data\images_augmented, degrees=0.0, deterministic=True, device=cpu, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, epochs=50, erasing=0.4, exist_ok=True, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=128, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=weights\yolov8n-cls.pt, momentum=0.937, mosaic=1.0, multi_scale=False, name=greenery_classification, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=20, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=..\runs, rect=False, resume=False, retina_masks=False, save=True, save_conf=False, save_crop=False, save_dir=D:\Dokumente\GeoAI\GeoAI_and_DL\runs\greenery_classification, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=classify, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# train: D:\Dokumente\GeoAI\GeoAI_and_DL\data\images_augmented\train... found 2260 images in 2 classes
# val: D:\Dokumente\GeoAI\GeoAI_and_DL\data\images_augmented\val... found 482 images in 2 classes
# test: D:\Dokumente\GeoAI\GeoAI_and_DL\data\images_augmented\test... found 442 images in 2 classes
# Overriding model.yaml nc=1000 with nc=2
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      7360  ultralytics.nn.modules.block.C2f             [32, 32, 1, True]
#   3                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   4                  -1  2     49664  ultralytics.nn.modules.block.C2f             [64, 64, 2, True]
#   5                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   6                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    460288  ultralytics.nn.modules.block.C2f             [256, 256, 1, True]
#   9                  -1  1    332802  ultralytics.nn.modules.head.Classify         [256, 2]
# YOLOv8n-cls summary: 56 layers, 1,440,850 parameters, 1,440,850 gradients, 3.4 GFLOPs
# Transferred 156/158 items from pretrained weights
# train: Fast image access  (ping: 0.10.0 ms, read: 0.60.2 MB/s, size: 5.4 KB)
# train: Scanning D:\Dokumente\GeoAI\GeoAI_and_DL\data\images_augmented\train... 2260 images, 0 corrupt: 100% ━━━━━━━━━━━━ 2260/2260 735.3it/s 3.1s<0.0s
# train: New cache created: D:\Dokumente\GeoAI\GeoAI_and_DL\data\images_augmented\train.cache
# val: Fast image access  (ping: 0.10.0 ms, read: 0.70.3 MB/s, size: 5.3 KB)
# val: Scanning D:\Dokumente\GeoAI\GeoAI_and_DL\data\images_augmented\val... 482 images, 0 corrupt: 100% ━━━━━━━━━━━━ 482/482 781.5it/s 0.6s0.0s
# val: New cache created: D:\Dokumente\GeoAI\GeoAI_and_DL\data\images_augmented\val.cache
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.001667, momentum=0.9) with parameter groups 26 weight(decay=0.0), 27 weight(decay=0.0005), 27 bias(decay=0.0)
# Image sizes 128 train, 128 val
# Using 0 dataloader workers
# Logging results to D:\Dokumente\GeoAI\GeoAI_and_DL\runs\greenery_classification
# Starting training for 50 epochs...
#
#       Epoch    GPU_mem       loss  Instances       Size
#        1/50         0G     0.4341          4        128: 100% ━━━━━━━━━━━━ 142/142 5.8it/s 24.6s0.3s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 16/16 10.5it/s 1.5s.2s
#                    all      0.952          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#        2/50         0G     0.2912          4        128: 100% ━━━━━━━━━━━━ 142/142 6.3it/s 22.6s0.3s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 16/16 12.2it/s 1.3s0.2s
#                    all      0.948          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#        3/50         0G     0.2771          4        128: 100% ━━━━━━━━━━━━ 142/142 6.0it/s 23.5s0.3s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 16/16 11.4it/s 1.4s0.2s
#                    all      0.942          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#        4/50         0G     0.2774          4        128: 100% ━━━━━━━━━━━━ 142/142 6.2it/s 23.1s0.3s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 16/16 12.3it/s 1.3s0.2s
#                    all      0.934          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#        5/50         0G     0.2841          4        128: 100% ━━━━━━━━━━━━ 142/142 5.9it/s 24.1s0.3s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 16/16 12.3it/s 1.3s0.2s
#                    all      0.963          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#        6/50         0G     0.2471          4        128: 100% ━━━━━━━━━━━━ 142/142 6.3it/s 22.6s0.3s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 16/16 11.7it/s 1.4s0.1s
#                    all      0.954          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#        7/50         0G     0.2184          4        128: 100% ━━━━━━━━━━━━ 142/142 6.0it/s 23.8s0.3s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 16/16 11.3it/s 1.4s.1s
#                    all      0.975          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#        8/50         0G      0.226          4        128: 100% ━━━━━━━━━━━━ 142/142 6.0it/s 23.7s0.3s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 16/16 11.3it/s 1.4s.1s
#                    all      0.942          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#        9/50         0G     0.2519          4        128: 100% ━━━━━━━━━━━━ 142/142 5.9it/s 24.0s0.3s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 16/16 11.6it/s 1.4s0.1s
#                    all      0.923          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       10/50         0G     0.2146          4        128: 100% ━━━━━━━━━━━━ 142/142 6.0it/s 23.6s0.3s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 16/16 11.9it/s 1.3s0.2s
#                    all      0.963          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       11/50         0G     0.2047          4        128: 100% ━━━━━━━━━━━━ 142/142 6.0it/s 23.8s0.3s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 16/16 11.3it/s 1.4s0.1s
#                    all      0.965          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       12/50         0G     0.1784          4        128: 100% ━━━━━━━━━━━━ 142/142 6.0it/s 23.6s0.3s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 16/16 11.2it/s 1.4s.1s
#                    all      0.981          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       13/50         0G      0.177          4        128: 100% ━━━━━━━━━━━━ 142/142 6.2it/s 22.9s0.3s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 16/16 11.5it/s 1.4s0.2s
#                    all      0.961          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       14/50         0G     0.1804          4        128: 100% ━━━━━━━━━━━━ 142/142 6.0it/s 23.5s0.3s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 16/16 11.5it/s 1.4s0.2s
#                    all      0.969          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       15/50         0G     0.1903          4        128: 100% ━━━━━━━━━━━━ 142/142 5.9it/s 24.3s0.3s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 16/16 11.3it/s 1.4s.2s
#                    all      0.965          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       16/50         0G     0.1791          4        128: 100% ━━━━━━━━━━━━ 142/142 6.0it/s 23.6s0.3s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 16/16 11.6it/s 1.4s0.2s
#                    all      0.977          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       17/50         0G     0.1972          4        128: 100% ━━━━━━━━━━━━ 142/142 6.0it/s 23.5s0.3s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 16/16 11.4it/s 1.4s0.1s
#                    all      0.983          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       18/50         0G      0.172          4        128: 100% ━━━━━━━━━━━━ 142/142 6.0it/s 23.7s0.3s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 16/16 11.6it/s 1.4s0.2s
#                    all      0.969          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       19/50         0G     0.1714          4        128: 100% ━━━━━━━━━━━━ 142/142 6.0it/s 23.5s0.3s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 16/16 11.5it/s 1.4s0.2s
#                    all       0.94          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       20/50         0G     0.1546          4        128: 100% ━━━━━━━━━━━━ 142/142 6.0it/s 23.7s0.3s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 16/16 11.4it/s 1.4s0.1s
#                    all      0.979          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       21/50         0G     0.1319          4        128: 100% ━━━━━━━━━━━━ 142/142 6.0it/s 23.5s0.3s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 16/16 11.4it/s 1.4s0.2s
#                    all      0.988          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       22/50         0G     0.1502          4        128: 100% ━━━━━━━━━━━━ 142/142 6.0it/s 23.7s0.3s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 16/16 11.2it/s 1.4s0.1s
#                    all      0.985          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       23/50         0G     0.1249          4        128: 100% ━━━━━━━━━━━━ 142/142 6.0it/s 23.6s0.3s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 16/16 10.9it/s 1.5s.2s
#                    all      0.979          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       24/50         0G     0.1412          4        128: 100% ━━━━━━━━━━━━ 142/142 5.9it/s 23.9s0.3s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 16/16 11.8it/s 1.4s0.2s
#                    all      0.985          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       25/50         0G     0.1298          4        128: 100% ━━━━━━━━━━━━ 142/142 5.9it/s 24.1s0.3s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 16/16 11.4it/s 1.4s0.1s
#                    all      0.985          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       26/50         0G     0.1427          4        128: 100% ━━━━━━━━━━━━ 142/142 6.0it/s 23.7s0.3s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 16/16 11.7it/s 1.4s0.2s
#                    all      0.979          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       27/50         0G       0.12          4        128: 100% ━━━━━━━━━━━━ 142/142 6.0it/s 23.7s0.3s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 16/16 11.6it/s 1.4s0.2s
#                    all       0.99          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       28/50         0G     0.1258          4        128: 100% ━━━━━━━━━━━━ 142/142 5.9it/s 24.0s0.3s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 16/16 11.6it/s 1.4s0.2s
#                    all      0.988          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       29/50         0G     0.1117          4        128: 100% ━━━━━━━━━━━━ 142/142 5.8it/s 24.6s0.3s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 16/16 11.4it/s 1.4s0.2s
#                    all       0.99          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       30/50         0G     0.1131          4        128: 100% ━━━━━━━━━━━━ 142/142 5.8it/s 24.6s0.3s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 16/16 11.2it/s 1.4s0.1s
#                    all      0.992          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       31/50         0G     0.1208          4        128: 100% ━━━━━━━━━━━━ 142/142 5.8it/s 24.4s0.3s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 16/16 11.4it/s 1.4s0.2s
#                    all      0.992          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       32/50         0G     0.1149          4        128: 100% ━━━━━━━━━━━━ 142/142 5.9it/s 24.0s0.3s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 16/16 11.5it/s 1.4s0.2s
#                    all      0.994          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       33/50         0G     0.1227          4        128: 100% ━━━━━━━━━━━━ 142/142 6.0it/s 23.9s0.3s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 16/16 11.7it/s 1.4s0.2s
#                    all      0.992          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       34/50         0G     0.1279          4        128: 100% ━━━━━━━━━━━━ 142/142 6.0it/s 23.7s0.3s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 16/16 11.7it/s 1.4s0.2s
#                    all      0.996          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       35/50         0G     0.1008          4        128: 100% ━━━━━━━━━━━━ 142/142 5.8it/s 24.5s0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 16/16 11.5it/s 1.4s0.2s
#                    all      0.994          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       36/50         0G     0.1095          4        128: 100% ━━━━━━━━━━━━ 142/142 5.9it/s 24.1s0.3s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 16/16 10.7it/s 1.5s0.1s
#                    all      0.994          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       37/50         0G     0.0992          4        128: 100% ━━━━━━━━━━━━ 142/142 5.9it/s 24.0s0.3s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 16/16 11.5it/s 1.4s0.2s
#                    all       0.99          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       38/50         0G     0.1036          4        128: 100% ━━━━━━━━━━━━ 142/142 5.7it/s 24.8s0.3s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 16/16 10.5it/s 1.5s.1s
#                    all       0.99          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       39/50         0G      0.106          4        128: 100% ━━━━━━━━━━━━ 142/142 5.8it/s 24.4s0.3s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 16/16 11.1it/s 1.4s.1s
#                    all      0.994          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       40/50         0G    0.09478          4        128: 100% ━━━━━━━━━━━━ 142/142 5.9it/s 24.0s0.3s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 16/16 11.1it/s 1.4s.2s
#                    all      0.994          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       41/50         0G    0.09138          4        128: 100% ━━━━━━━━━━━━ 142/142 5.8it/s 24.6s0.3s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 16/16 11.7it/s 1.4s0.2s
#                    all      0.992          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       42/50         0G    0.09396          4        128: 100% ━━━━━━━━━━━━ 142/142 6.0it/s 23.8s0.3s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 16/16 10.9it/s 1.5s0.2s
#                    all      0.988          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       43/50         0G    0.08296          4        128: 100% ━━━━━━━━━━━━ 142/142 5.9it/s 24.1s0.3s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 16/16 11.1it/s 1.4s0.2s
#                    all      0.985          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       44/50         0G    0.07933          4        128: 100% ━━━━━━━━━━━━ 142/142 5.7it/s 24.9s0.3s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 16/16 11.2it/s 1.4s.2s
#                    all      0.992          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       45/50         0G    0.08445          4        128: 100% ━━━━━━━━━━━━ 142/142 5.9it/s 24.1s0.3s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 16/16 11.1it/s 1.4s.1s
#                    all      0.994          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       46/50         0G    0.07892          4        128: 100% ━━━━━━━━━━━━ 142/142 5.9it/s 24.0s0.3s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 16/16 11.6it/s 1.4s0.2s
#                    all      0.992          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       47/50         0G    0.09669          4        128: 100% ━━━━━━━━━━━━ 142/142 6.1it/s 23.4s0.3s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 16/16 11.3it/s 1.4s0.1s
#                    all      0.996          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       48/50         0G    0.09086          4        128: 100% ━━━━━━━━━━━━ 142/142 5.8it/s 24.4s0.3s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 16/16 9.9it/s 1.6s0.2s
#                    all      0.994          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       49/50         0G    0.07918          4        128: 100% ━━━━━━━━━━━━ 142/142 5.9it/s 24.1s0.3s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 16/16 11.1it/s 1.4s.1s
#                    all      0.996          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       50/50         0G    0.06874          4        128: 100% ━━━━━━━━━━━━ 142/142 6.0it/s 23.5s0.3s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 16/16 10.8it/s 1.5s.1s
#                    all      0.996          1
#
# 50 epochs completed in 0.353 hours.
# Optimizer stripped from D:\Dokumente\GeoAI\GeoAI_and_DL\runs\greenery_classification\weights\last.pt, 3.0MB
# Optimizer stripped from D:\Dokumente\GeoAI\GeoAI_and_DL\runs\greenery_classification\weights\best.pt, 3.0MB
#
# Validating D:\Dokumente\GeoAI\GeoAI_and_DL\runs\greenery_classification\weights\best.pt...
# Ultralytics 8.3.228  Python-3.11.3 torch-2.9.1+cpu CPU (AMD Ryzen 5 2600 Six-Core Processor)
# YOLOv8n-cls summary (fused): 30 layers, 1,437,442 parameters, 0 gradients, 3.3 GFLOPs
# train: D:\Dokumente\GeoAI\GeoAI_and_DL\data\images_augmented\train... found 2260 images in 2 classes
# val: D:\Dokumente\GeoAI\GeoAI_and_DL\data\images_augmented\val... found 482 images in 2 classes
# test: D:\Dokumente\GeoAI\GeoAI_and_DL\data\images_augmented\test... found 442 images in 2 classes
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 16/16 11.2it/s 1.4s0.1s
#                    all      0.996          1
# Speed: 0.0ms preprocess, 1.5ms inference, 0.0ms loss, 0.0ms postprocess per image
# Results saved to D:\Dokumente\GeoAI\GeoAI_and_DL\runs\greenery_classification
#
#  Best model saved at: ..\runs\greenery_classification\weights\best.pt
# Ultralytics 8.3.228  Python-3.11.3 torch-2.9.1+cpu CPU (AMD Ryzen 5 2600 Six-Core Processor)
# YOLOv8n-cls summary (fused): 30 layers, 1,437,442 parameters, 0 gradients, 3.3 GFLOPs
# train: D:\Dokumente\GeoAI\GeoAI_and_DL\data\images_augmented\train... found 2260 images in 2 classes
# val: D:\Dokumente\GeoAI\GeoAI_and_DL\data\images_augmented\val... found 482 images in 2 classes
# test: D:\Dokumente\GeoAI\GeoAI_and_DL\data\images_augmented\test... found 442 images in 2 classes
# val: Fast image access  (ping: 0.10.0 ms, read: 45.922.4 MB/s, size: 5.3 KB)
# val: Scanning D:\Dokumente\GeoAI\GeoAI_and_DL\data\images_augmented\val... 482 images, 0 corrupt: 100% ━━━━━━━━━━━━ 482/482 481.6Kit/s 0.0s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 31/31 19.4it/s 1.6s0.1s
#                    all      0.996          1
# Speed: 0.0ms preprocess, 1.9ms inference, 0.0ms loss, 0.0ms postprocess per image
# Results saved to D:\Dokumente\GeoAI\GeoAI_and_DL\runs\classify\val
#
# 📊 Validation Top-1 Accuracy: 99.59%
# Ultralytics 8.3.228  Python-3.11.3 torch-2.9.1+cpu CPU (AMD Ryzen 5 2600 Six-Core Processor)
# train: D:\Dokumente\GeoAI\GeoAI_and_DL\data\images_augmented\train... found 2260 images in 2 classes
# val: D:\Dokumente\GeoAI\GeoAI_and_DL\data\images_augmented\val... found 482 images in 2 classes
# test: D:\Dokumente\GeoAI\GeoAI_and_DL\data\images_augmented\test... found 442 images in 2 classes
# test: Fast image access  (ping: 0.10.0 ms, read: 51.813.4 MB/s, size: 6.9 KB)
# test: Scanning D:\Dokumente\GeoAI\GeoAI_and_DL\data\images_augmented\test... 442 images, 0 corrupt: 100% ━━━━━━━━━━━━ 442/442 908.0it/s 0.5s0.1s
# test: New cache created: D:\Dokumente\GeoAI\GeoAI_and_DL\data\images_augmented\test.cache
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 28/28 19.4it/s 1.4s0.1s
#                    all       0.93          1
# Speed: 0.0ms preprocess, 1.8ms inference, 0.0ms loss, 0.0ms postprocess per image
# Results saved to D:\Dokumente\GeoAI\GeoAI_and_DL\runs\classify\val2
#
# 📊 Test Top-1 Accuracy: 92.99%
#
#  Predictions for 20 sample images:
#
# ✅ Mlalakua_Merged_PPK_ycbr_test_patch_1001.jpg True: greenery      | Pred: greenery      (99.91%)
# ✅ Mlalakua_Merged_PPK_ycbr_test_patch_1001_aug_39.jpg True: greenery      | Pred: greenery      (99.98%)
# ❌ Mlalakua_Merged_PPK_ycbr_test_patch_1130.jpg True: greenery      | Pred: non_greenery  (93.76%)
# ❌ Mlalakua_Merged_PPK_ycbr_test_patch_1130_aug_0.jpg True: greenery      | Pred: non_greenery  (61.83%)
# ✅ Mlalakua_Merged_PPK_ycbr_test_patch_1259.jpg True: greenery      | Pred: greenery      (95.83%)
# ✅ Mlalakua_Merged_PPK_ycbr_test_patch_1259_aug_31.jpg True: greenery      | Pred: greenery      (96.00%)
# ✅ Mlalakua_Merged_PPK_ycbr_test_patch_1259_aug_99.jpg True: greenery      | Pred: greenery      (99.75%)
# ✅ Mlalakua_Merged_PPK_ycbr_test_patch_1311.jpg True: greenery      | Pred: greenery      (99.89%)
# ✅ Mlalakua_Merged_PPK_ycbr_test_patch_1314.jpg True: greenery      | Pred: greenery      (99.96%)
# ✅ Mlalakua_Merged_PPK_ycbr_test_patch_132.jpg True: greenery      | Pred: greenery      (98.77%)
# ❌ Mlalakua_Merged_PPK_ycbr_test_patch_104.jpg True: non_greenery  | Pred: greenery      (88.10%)
# ✅ Mlalakua_Merged_PPK_ycbr_test_patch_1142.jpg True: non_greenery  | Pred: non_greenery  (99.79%)
# ✅ Mlalakua_Merged_PPK_ycbr_test_patch_119.jpg True: non_greenery  | Pred: non_greenery  (99.87%)
# ✅ Mlalakua_Merged_PPK_ycbr_test_patch_1196.jpg True: non_greenery  | Pred: non_greenery  (100.00%)
# ✅ Mlalakua_Merged_PPK_ycbr_test_patch_1211.jpg True: non_greenery  | Pred: non_greenery  (100.00%)
# ✅ Mlalakua_Merged_PPK_ycbr_test_patch_1233.jpg True: non_greenery  | Pred: non_greenery  (67.56%)
# ✅ Mlalakua_Merged_PPK_ycbr_test_patch_1243.jpg True: non_greenery  | Pred: non_greenery  (98.04%)
# ✅ Mlalakua_Merged_PPK_ycbr_test_patch_1245.jpg True: non_greenery  | Pred: non_greenery  (99.50%)
# ✅ Mlalakua_Merged_PPK_ycbr_test_patch_1276.jpg True: non_greenery  | Pred: non_greenery  (99.44%)
# ✅ Mlalakua_Merged_PPK_ycbr_test_patch_1328.jpg True: non_greenery  | Pred: non_greenery  (99.05%)
#
#  PIPELINE COMPLETE!
# All results saved in: ..\runs\greenery_classification
